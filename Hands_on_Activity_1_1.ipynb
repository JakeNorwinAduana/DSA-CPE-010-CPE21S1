# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeNorwinAduana/DSA-CPE-010-CPE21S1/blob/main/Hands_on_Activity_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Problem 2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#     Additional activities:
#     1. Algorithm for Finding the sum of the numbers 2, 4, 6, 8, ..., n:
#     start
#     sum = 0
#     get an even value
#     sum = sum + 2
#     output sum
#     if sum = value
#     repeat step 4
#     else
#     end
#     2. Write an algorithm to read 100 numbers then display the sum.
#     start
#     sum = 0
#     get a value 100 times
#     sum = sum + value
#     repeat step 4 100 times
#     output sum
#     end
#     3. Write an algorithm to read two numbers then display the largest
#     start
#     get 2 values
#     if value 1 > value 2
#     output value 1
#     else
#     output value 2
#     end
#     4. Write an algorithm to read two numbers then display the smallest
#     start
#     get 2 values
#     if value 1 > value 2
#     output value 2
#     else
#     outpus value 1
#     end
#     5. Write an algorithm to read three numbers then display the largest.
#     start
#     get 3 values
#     if value 1 > value 2 > value 3
#     output value 1
#     else if value 1 < value 2 > value 3
#     outpus value 2
#     else
#     output value 3
#     end
#     6. Write an algorithm to read 100 numbers then display the largest.
#     start
#     get 100 values
#     value_counter = 0
#     value = largest number
#     if value_counter <= 100
#       get a value
#       if largest number < next value
#       next value = largest number
#       else if largest number > next value
#       repeat step 4
#     else
#     output value
