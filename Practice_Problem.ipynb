# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeNorwinAduana/DSA-CPE-010-CPE21S1/blob/main/Practice_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#     Algorithm:
#
#     Start
#     Sum = 0
#     whele ther is value to get
#     Get value
#     If value is even
#     sum += value
#     else
#     go to step 4
#     end

# %% [markdown]
#     Flow Chart
# ![unnamed.png](data:image/png;base64,...)

# %%
sum = 0
x = [26,49,98,87,62,75]
for i in range(len(x)):
  if x[i] % 2 == 0:
    sum += x[i]
print(sum)
# Out:
# 186
